# %%
# Add relevant Jupyter notebook extensions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Add relevant Jupyter notebook extensions
# ----> 2 cd /path/to/b1-coding-practical
#
# NameError: name 'cd' is not defined

# %%
# You can double-check your Python path like this...
import sys  
print(sys.path)
# Out:
# ['/Users/oliverzhou/Library/CloudStorage/OneDrive-Nexus365/Engineering/B1 Engineering Computation/1. Scientific Coding/scientific_coding_practical/b1-coding-practical', '/Users/oliverzhou/Library/CloudStorage/OneDrive-Nexus365/Engineering/B1 Engineering Computation/1. Scientific Coding/scientific_coding_practical/b1-coding-practical/notebooks', '/opt/anaconda3/lib/python312.zip', '/opt/anaconda3/lib/python3.12', '/opt/anaconda3/lib/python3.12/lib-dynload', '', '/Users/oliverzhou/Library/CloudStorage/OneDrive-Nexus365/Engineering/B1 Engineering Computation/1. Scientific Coding/scientific_coding_practical/b1-coding-practical/.venv/lib/python3.12/site-packages']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Import relevant modules

from uuv_mission.dynamic import Submarine, ClosedLoop, Mission
from uuv_mission.control import pd_controller as controller

sub = Submarine()
# Instantiate your controller (depending on your implementation)
closed_loop = ClosedLoop(sub, controller)
mission = Mission.from_csv("/Users/oliverzhou/Library/CloudStorage/OneDrive-Nexus365/Engineering/B1 Engineering Computation/1. Scientific Coding/scientific_coding_practical/b1-coding-practical/data/mission.csv")
# Absolute file path used to access the csv file to ensure no mistakes

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
